# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
def show(img):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    imshow(img_rgb)

# %%
def gaussiantest(arg1,arg2):
    img = cv.imread("apple.jpg")
    imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    thresh = cv2.GaussianBlur(thresh,(arg1,arg2),0)
    im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    imshow(thresh)

# %%
gaussiantest(5,5)

# %%
gaussiantest(10,10)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-34-1ce9a614abbe> in <module>()
# ----> 1 gaussiantest(10,10)
#
# <ipython-input-32-4760b1525d20> in gaussiantest(arg1, arg2)
#       3     imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       4     ret, thresh = cv2.threshold(imgray, 127, 255, 0)
# ----> 5     thresh = cv2.GaussianBlur(thresh,(arg1,arg2),0)
#       6     im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#       7     imshow(thresh)
#
# error: C:\projects\opencv-python\opencv\modules\imgproc\src\smooth.cpp:1780: error: (-215) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function cv::createGaussianKernels

# %%
blur2 = cv.GaussianBlur(img,(5,5),0)
show(blur2)

# %%
blur = cv.GaussianBlur(img,(15,15),0)
show(blur)
