# %%
from keras.models import load_model
# Out:
# /Users/anais/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = load_model("weights-improvement-48-0.42.hdf5")
# Out:
# /Users/anais/miniconda3/lib/python3.6/site-packages/keras/models.py:291: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

import keras
from keras.preprocessing import image
from keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
image_size = (150, 150)
image_path = "../test.png"
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
# Refactor above steps into reusable function
def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3))

# %%
predict(image_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f9e286696c48> in <module>()
# ----> 1 predict(image_path)
#
# <ipython-input-24-50173c244523> in predict(image_path)
#       8     predictions = model.predict(x)
#       9     plt.imshow(img)
# ---> 10     print('Predicted:', decode_predictions(predictions, top=3))
#
# ~/miniconda3/lib/python3.6/site-packages/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     200                          'a batch of predictions '
#     201                          '(i.e. a 2D array of shape (samples, 1000)). '
# --> 202                          'Found array with shape: ' + str(preds.shape))
#     203     if CLASS_INDEX is None:
#     204         fpath = get_file('imagenet_class_index.json',
#
# ValueError: `decode_predictions` expects a batch of predictions (i.e. a 2D array of shape (samples, 1000)). Found array with shape: (1, 81)
