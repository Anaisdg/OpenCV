# %%
import pandas as pd
test_list = [['1','D','R','S'],
             ['2','D','P','E'],
             ['3','D','P','E'],
             ['1','D','P','E'],
            ['2','S','G','S'],
            ['2','O','G','E'],
            ['2','D','P','E'],
            ['3','D','R','F'],
            ['1','O','R','F'],
            ['2','O','R','F'],
            ['3','O','R','F'],
            ['1','D','R','F'],
            ['2','D','R','F'],
            ['3','D','R','F'],
            ['1','S','G','F'],
            ['2','S','G','F']]

# %%
def unpack(cards):
    number = []
    shape = []
    color = []
    shading = []

    for card in cards:
        number.append(card[0])
        shape.append(card[1])
        shading.append(card[2])
    df = pd.DataFrame({'number':number,'shape':shape,'shading':shading})
    return df

# %%
hello = unpack(test_list)

# %%
hello
# Out:
#    color number shading shape
# 0      R      1       S     D
# 1      P      2       E     D
# 2      P      3       E     D
# 3      P      1       E     D
# 4      G      2       S     S
# 5      G      2       E     O
# 6      P      2       E     D
# 7      R      3       F     D
# 8      R      1       F     O
# 9      R      2       F     O
# 10     R      3       F     O
# 11     R      1       F     D
# 12     R      2       F     D
# 13     R      3       F     D
# 14     G      1       F     S
# 15     G      2       F     S

# %%
squares = {1: 1, 3: 9, 5: 25, 7: 49, 9: 81}
for i in squares:
    print(squares[i])

# %%
for single_list in test_list:
 

    test_dict["number"] = single_list[0]
    test_dict["shape"] =single_list[1]
