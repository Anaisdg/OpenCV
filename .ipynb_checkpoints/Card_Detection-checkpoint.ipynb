# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import math
# %matplotlib inline

# %%
def Imagedetection(imagepath,numcards,imagename="defaultname",epsilon=0.02):
    img = cv2.imread(imagepath)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(1,1),1000)
    flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
    # Find contours
    image,contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=cv2.contourArea,reverse = True) 
    # Select long perimeters only
    perimeters = [cv2.arcLength(contours[i],True) for i in range(len(contours))]
    listindex=[i for i in range(numcards) if perimeters[i]>perimeters[0]/2]
    # Show image
    imgcont = img.copy()
    [cv2.drawContours(imgcont, [contours[i]], 0, (0,255,0), 5) for i in listindex]
   
    warp = list(range(numcards))
    
    for i in range(numcards):
        card = contours[i]
        while approx.shape != (4,2)
        peri = 0.02* cv2.arcLength(card,True)
        approx = cv2.approxPolyDP(card,peri,True)
        rect = cv2.minAreaRect(contours[i])
        r = cv2.boxPoints(rect)

        h = np.float32([[0,0],[399,0],[399,399],[0,399]])
        approx = np.float32([item for sublist in approx for item in sublist])
#         print(approx.shape)
        transform = cv2.getPerspectiveTransform(approx,h)
        warp[i] = cv2.warpPerspective(img,transform,(400,400))

    # Show perspective correction
    
    fig = plt.figure(1, (10,10))
    grid = ImageGrid(fig, 111, # similar to subplot(111)
                    nrows_ncols = (4, 4), # creates 2x2 grid of axes
                    axes_pad=0.1, # pad between axes in inch.
                    aspect=True, # do not force aspect='equal'
                    )
    new_img_list = []
    for i in range(numcards):
        new_img = cv2.cvtColor(warp[i],cv2.COLOR_BGR2RGB)
        new_img_list.append(new_img)
        grid[i].imshow(new_img)
        cv2.imwrite(f"{imagename}{i}.jpg",wrap[i])
    print("Cropping Complete! Let's roll!")
    return new_img_list
# Out:
#   File "<ipython-input-4-bd6e47493648>", line 20
#     while approx.shape != (4,2)
#                                ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import cv2
import math


def Imagedetection(imagepath,numcards,epsilon=0.02):
    img = cv2.imread(imagepath)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(1,1),1000)
    flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
    # Find contours
    image,contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=cv2.contourArea,reverse=True) 
    # Select long perimeters only
    perimeters = [cv2.arcLength(contours[i],True) for i in range(len(contours))]
    listindex=[i for i in range(numcards) if perimeters[i]>perimeters[0]/2]
    # Show image
    imgcont = img.copy()
    [cv2.drawContours(imgcont, [contours[i]], 0, (0,255,0), 5) for i in listindex]
   
    warp = list(range(numcards))
    
    for i in range(numcards):
        card = contours[i]
        peri = cv2.arcLength(card,True)
        
     
        approx = cv2.approxPolyDP(card,epsilon*peri,True)
        rect = cv2.minAreaRect(contours[i])
        r = cv2.boxPoints(rect)

        h = np.float32([[0,0],[399,0],[399,399],[0,399]])
        approx = np.float32([item for sublist in approx for item in sublist])
        print(approx.shape)
            
        transform = cv2.getPerspectiveTransform(approx,h)
        warp[i] = cv2.warpPerspective(img,transform,(400,400))

    # Show perspective correction
    new_img_list = []
    for i in range(numcards):
        new_img = cv2.cvtColor(warp[i],cv2.COLOR_BGR2RGB)
        new_img_list.append(new_img)
        
        cv2.imwrite(f"Result_Folder/Image{i}.jpg",warp[i])
    print("Cropping Complete! Let's roll!")

# %%
Imagedetection("../image.jpg",12,0.03)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-14-fc4b957d3e5a> in <module>()
# ----> 1 Imagedetection("../image.jpg",12,0.03)
#
# <ipython-input-5-aac6dd0f99a2> in Imagedetection(imagepath, numcards, epsilon)
#       6 def Imagedetection(imagepath,numcards,epsilon=0.02):
#       7     img = cv2.imread(imagepath)
# ----> 8     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       9     blur = cv2.GaussianBlur(gray,(1,1),1000)
#      10     flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:11111: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
from os import listdir
from os.path import isfile, join
import numpy
import cv2

mypath='YUKUN PICTURES'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = numpy.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
    images[n] = cv2.imread(join(mypath,onlyfiles[n]) )
    Imagedetection(images[n],12)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-98e2703081f6> in <module>()
#       5
#       6 mypath='YUKUN PICTURES'
# ----> 7 onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
#       8 images = numpy.empty(len(onlyfiles), dtype=object)
#       9 for n in range(0, len(onlyfiles)):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'YUKUN PICTURES'

# %%
Imagedetection("YUKUN PICTURES/_MG_4594.JPG",12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5ca272e8a071> in <module>()
# ----> 1 Imagedetection("YUKUN PICTURES/_MG_4594.JPG",12)
#
# <ipython-input-28-bb5ff164e656> in Imagedetection(img, numcards, epsilon)
#       5
#       6 def Imagedetection(img,numcards,epsilon=0.02):
# ----> 7     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       8     blur = cv2.GaussianBlur(gray,(1,1),1000)
#       9     flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
#
# TypeError: src is not a numpy array, neither a scalar

# %%
def Imagedetection1(imagepath,numcards,epsilon=0.02):
    img = cv2.imread(imagepath)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray,(1,1),1000)
    flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
    # Find contours
    image,contours, hierarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=cv2.contourArea,reverse=True)[:numcards] 
    print(len(contours))
    # Select long perimeters only
    perimeters = [cv2.arcLength(contours[i],True) for i in range(len(contours))]
    listindex=[i for i in range(numcards) if perimeters[i]>perimeters[0]/2]
    # Show image
    imgcont = img.copy()
    [cv2.drawContours(imgcont, [contours[i]], 0, (255,0,0), 5) for i in listindex]
    draw_cont = [cv2.drawContours(imgcont, [contours[i]], 0, (255,0,0), 5) for i in listindex]
    
    print("perimeters:" , len(perimeters))
    print("contour len:" , len(contours))
    print("draw_cont:" , len(draw_cont))
    print("listindex:" , len(listindex))
    
   
    warp = list(range(numcards))
    
    for i in range(numcards):
        card = contours[i]
        peri = cv2.arcLength(card,True)
        approx = cv2.approxPolyDP(card,epsilon*peri,True)
        rect = cv2.minAreaRect(contours[i])
        r = cv2.boxPoints(rect)

        h = np.float32([[0,0],[399,0],[399,399],[0,399]])
        approx = np.float32([item for sublist in approx for item in sublist])
        print(approx.shape)
        transform = cv2.getPerspectiveTransform(approx,h)
        warp[i] = cv2.warpPerspective(img,transform,(400,400))

    # Show perspective correction
    new_img_list = []
    for i in range(numcards):
        new_img = cv2.cvtColor(warp[i],cv2.COLOR_BGR2RGB)
        new_img_list.append(new_img)
        
        cv2.imwrite(f"Image{i}.jpg",warp[i])
    print(new_img)
    print("Cropping Complete! Let's roll!")
    print(len(new_img_list))

# %%
testone = "IMG_1817.JPG"
testtwo = "../Denmo3.jpg"
fail = "IMG_1850.JPG"
nochange ="IMG_1830.JPG"

# %%
# img = cv2.imread(testone)
# new_img_2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# plt.figure(figsize=(10,10))
# plt.imshow(new_img_2)

# %%
Imagedetection1(testone,12)
# Out:
# 12
# perimeters: 12
# contour len: 12
# draw_cont: 12
# listindex: 12
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# [[[138 121 111]
#   [150 134 121]
#   [157 141 128]
#   ...
#   [192 176 160]
#   [179 163 147]
#   [147 131 116]]
#
#  [[155 139 126]
#   [168 152 139]
#   [184 168 155]
#   ...
#   [213 197 181]
#   [209 193 177]
#   [189 173 157]]
#
#  [[166 150 137]
#   [179 163 150]
#   [196 180 167]
#   ...
#   [225 210 194]
#   [225 209 193]
#   [209 193 177]]
#
#  ...
#
#  [[196 180 165]
#   [203 187 172]
#   [206 190 175]
#   ...
#   [188 175 158]
#   [181 168 151]
#   [172 159 142]]
#
#  [[171 154 140]
#   [180 163 149]
#   [185 169 155]
#   ...
#   [181 168 151]
#   [173 160 143]
#   [158 145 129]]
#
#  [[141 123 111]
#   [134 116 104]
#   [147 129 117]
#   ...
#   [169 156 140]
#   [138 125 109]
#   [137 124 108]]]
# Cropping Complete! Let's roll!
# 12

# %%
new_img_3 = cv2.cvtColor(new_img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(new_img_3)

# %%
def Imagedetection2(imagepath,numcards,epsilon):
        img = cv2.imread(imagepath)
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        blur = cv2.GaussianBlur(gray,(1,1),1000)
        flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)
        # Find contours
        image,contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        contours = sorted(contours, key=cv2.contourArea,reverse=True) 
        # Select long perimeters only
        perimeters = [cv2.arcLength(contours[i],True) for i in range(len(contours))]
        listindex=[i for i in range(numcards) if perimeters[i]>perimeters[0]/2]
        # Show image
        imgcont = img.copy()
        [cv2.drawContours(imgcont, [contours[i]], 0, (0,255,0), 5) for i in listindex]

        warp = list(range(numcards))
        
        print(contours)
        assert len(contours) == numcards
        
        for i in range(numcards):
            card = contours[i]
            peri = cv2.arcLength(card,True)
            approx = cv2.approxPolyDP(card,epsilon*peri,True)
            rect = cv2.minAreaRect(contours[i])
            r = cv2.boxPoints(rect)

            h = np.float32([[0,0],[399,0],[399,399],[0,399]])
            approx = np.float32([item for sublist in approx for item in sublist])
            print(approx.shape)
            transform = cv2.getPerspectiveTransform(approx,h)
            warp[i] = cv2.warpPerspective(img,transform,(400,400))

        # Show perspective correction
        new_img_list = []
        for i in range(numcards):
            new_img = cv2.cvtColor(warp[i],cv2.COLOR_BGR2RGB)
            new_img_list.append(new_img)

            cv2.imwrite(f"Image{i}.jpg",warp[i])
        print("Cropping Complete! Let's roll!")
        
        return len(new_)
        
for i in range(100):
    epsilon = i/100
    try: 
        Imagedetection2(fail,12,epsilon)

    except Exception as e: 
        print(e)

    i = i + 1
# Out:
# (12, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (3, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (4, 2)
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (2, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform
#
# (1, 2)
# /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform

# %%
Imagedetection2(fail, 12)
# Out:
# (4, 2)
# (4, 2)
# (3, 2)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-73-163d489f69d2> in <module>()
# ----> 1 Imagedetection2(fail, 12)
#
# <ipython-input-51-c707d6a99562> in Imagedetection2(imagepath, numcards, epsilon)
#      26         approx = np.float32([item for sublist in approx for item in sublist])
#      27         print(approx.shape)
# ---> 28         transform = cv2.getPerspectiveTransform(approx,h)
#      29         warp[i] = cv2.warpPerspective(img,transform,(400,400))
#      30
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform

# %%
len(Imagedetection2(fail,12))
# Out:
# (4, 2)
# (4, 2)
# (3, 2)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-53-fe64487a6778> in <module>()
# ----> 1 len(Imagedetection2(fail,12))
#
# <ipython-input-51-c707d6a99562> in Imagedetection2(imagepath, numcards, epsilon)
#      26         approx = np.float32([item for sublist in approx for item in sublist])
#      27         print(approx.shape)
# ---> 28         transform = cv2.getPerspectiveTransform(approx,h)
#      29         warp[i] = cv2.warpPerspective(img,transform,(400,400))
#      30
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/imgwarp.cpp:3232: error: (-215) src.checkVector(2, 5) == 4 && dst.checkVector(2, 5) == 4 in function getPerspectiveTransform

# %%
# img = cv2.imread(testone)
# gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# blur = cv2.GaussianBlur(gray,(5,5),2)
# flag, thresh = cv2.threshold(blur, 120, 255, cv2.THRESH_BINARY)

# image,contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# new_img= cv2.drawContours(img,contours, -1, (0,255,), 3)
# # contours = sorted(contours, key=cv2.contourArea,reverse=True)
# # perimeters = [cv2.arcLength(contours[i],True) for i in range(len(contours))]
# # listindex=[i for i in range(1) if perimeters[i]>perimeters[0]/2]
# # new_img_2 = [cv2.drawContours(img, [contours[i]], 0, (0,255,0), 5) for i in listindex]
# # plt.imshow(new_img_2)

# # x, y = [], []

# # for contour_line in contours:
# #     for contour in contour_line:
# #         x.append(contour[0][0])
# #         y.append(contour[0][1])

# # x1, x2, y1, y2 = min(x), max(x), min(y), max(y)

# %%
len((2,2))
# Out:
# 2
